# %% [markdown]
# <a href="https://colab.research.google.com/github/shb2908/FMML-230032-/blob/main/FMML_Module4_Lab3_2024(soham_bose).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad
# # Module 4: Perceptron and Gradient Descent
# ## Lab 3: Gradient Descent
#
# Gradient descent is a very important algorithm to understand, as it underpins many of the more advanced algorithms used in Machine Learning and Deep Learning.
#
# A brief overview of the algorithm is
#
#
# *   start with a random initialization of the solution.
# *   incrementally change the solution by moving in the direction of negative gradient of the objective function.
# *   repeat the previous step until some convergence criteria is met.
#
# The key equation for change in weight is:
# $$w^{k+1} \leftarrow w^k - \eta \Delta J$$
#
# In this lab, we will discuss stochastic gradient descent, mini-batch gradient descent and batch gradient descent.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %% [markdown]
# # Creating the Data
#
# Let's generate some data with:
# \begin{equation} y_0= 4 \end{equation}
# \begin{equation} y_1= 3 \end{equation}
#
# and also add some noise to the data.

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %% [markdown]
# Let's also plot the data we just created

# %%
plt.plot(X, y, 'b.')
plt.xlabel('x')
plt.ylabel('y', rotation=0)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Cost Function
#
# The equation for calculating cost function is as shown below. The cost function is only for linear regression. For other algorithms, the cost function will be different and the gradients would have to be derived from the cost functions
#
# \begin{equation}
# J(y_{pred}) = \frac{1}{2} m \sum_{i=1}^{m} (h(y_{pred})^{(i)} - y^{(i)})^2
# \end{equation}

# %%
def cal_cost(y_pred, X, y):
    '''
    Calculates the cost for given X and Y.
    y_pred = Vector of y_preds
    X = Row of X's np.zeros((2, j))
    y = Actual y's np.zeros((2, 1))

    where:
        j is the no of features
    '''

    m = len(y)

    predictions = X.dot(y_pred)
    cost = (1 / 2 * m) * np.sum(np.square(predictions - y))

    return cost

# %% [markdown]
# ## Gradients
#
# \begin{equation}
# y_{pred_0}: = y_{pred_0} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}
# \begin{equation}
# y_{pred_1}: = y_{pred_1} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}
# .
#
# .
#
# .
#
# .
#
# \begin{equation}
# y_{pred_j}: = y_{pred_j} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}

# %%
def gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=100):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final y_pred vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    y_pred_history = np.zeros((iterations, 2))

    for it in range(iterations):
        prediction = np.dot(X, y_pred)
        y_pred = y_pred - (1 / m) * learning_rate * (X.T.dot((prediction - y)))
        y_pred_history[it,:] = y_pred.T
        cost_history[it]  = cal_cost(y_pred, X, y)

    return y_pred, cost_history, y_pred_history

# %% [markdown]
# Let's do 1000 iterations with a learning rate of 0.01.
# We will start with a random prediction.

# %%
lr = 0.01
n_iter = 1000

y_pred = np.random.randn(2,1)
X_b = np.c_[np.ones((len(X), 1)), X]
y_pred, cost_history, y_pred_history = gradient_descent(X_b, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 3.903
# y_pred[1]: 3.046
# Final error: 4180.375

# %% [markdown]
# Plotting the error vs Number of iterations

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# Zooming in...

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(range(200), cost_history[:200], 'b.')

# %% [markdown]
# # Stochastic Gradient Descent

# %% [markdown]
# In Batch Gradient Descent we were considering all the examples for every step of Gradient Descent. But what if our dataset is very huge. Deep learning models crave for data. The more the data the more chances of a model to be good. Suppose our dataset has 5 million examples, then just to take one step the model will have to calculate the gradients of all the 5 million examples. This does not seem an efficient way. To tackle this problem we have Stochastic Gradient Descent. In Stochastic Gradient Descent (SGD), we consider just one example at a time to take a single step.

# %%
def stocashtic_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    y_pred = Vector of y_pred np.random.randn(j,1)
    learning_rate
    iterations = no of iterations

    Returns the final y_pred vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)

    for it in range(iterations):
        cost = 0.0

        for i in range(m):
            rand_ind = np.random.randint(0,m)
            X_i = X[rand_ind, :].reshape(1, X.shape[1])
            y_i = y[rand_ind].reshape(1,1)
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate *(X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i)

        cost_history[it]  = cost

    return y_pred, cost_history

# %%
lr = 0.5
n_iter = 50
y_pred = np.random.randn(2, 1)
X_b = np.c_[np.ones((len(X), 1)), X]
y_pred, cost_history = stocashtic_gradient_descent(X_b, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.121
# y_pred[1]: 2.755
# Final error: 41.313

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# # Mini Batch Gradient Descent

# %% [markdown]
# We have seen the Batch Gradient Descent. We have also seen the Stochastic Gradient Descent. Batch Gradient Descent can be used for smoother curves. SGD can be used when the dataset is large. Batch Gradient Descent converges directly to minima. SGD converges faster for larger datasets. But, since in SGD we use only one example at a time, we cannot implement the vectorized implementation on it. This can slow down the computations. To tackle this problem, a mixture of Batch Gradient Descent and SGD is used.
# Neither we use all the dataset all at once nor we use the single example at a time. We use a batch of a fixed number of training examples which is less than the actual dataset and call it a mini-batch. Doing this helps us achieve the advantages of both the former variants we saw.

# %%
def minibatch_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10, batch_size=20):
    '''
    X = Matrix of X without added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final theta vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    n_batches = int(m / batch_size)

    for it in range(iterations):
        cost = 0.0
        indices = np.random.permutation(m)
        X = X[indices]
        y = y[indices]

        for i in range(0, m, batch_size):
            X_i = X[i: i + batch_size]
            y_i = y[i: i + batch_size]

            X_i = np.c_[np.ones(len(X_i)), X_i]
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate * (X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i)

        cost_history[it]  = cost

    return y_pred, cost_history

# %%
lr = 0.1
n_iter = 200
y_pred = np.random.randn(2,1)
y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.148
# y_pred[1]: 2.827
# Final error: 807.488

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# Things to try out:
#
# 1. Change batch size in mini-batch gradient descent.
# 2. Test all the three out on real datasets.
# 3. Compare the effects of changing learning rate by the same amount in Batch GD, SGD and Mini-batch GD.

# %%
def minibatch_gradient_descent(X, y, y_pred, learning_rate=0.001, iterations=15, batch_size=25):
    '''
    X = Matrix of X without added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final theta vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    n_batches = int(m / batch_size)

    for it in range(iterations):
        cost = 0.0
        indices = np.random.permutation(m)
        X = X[indices]
        y = y[indices]

        for i in range(0, m, batch_size):
            X_i = X[i: i + batch_size]
            y_i = y[i: i + batch_size]

            X_i = np.c_[np.ones(len(X_i)), X_i]
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate * (X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i)

        cost_history[it]  = cost

    return y_pred, cost_history

# %%
lr = 0.1
n_iter = 200
y_pred = np.random.randn(2,1)
y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.248
# y_pred[1]: 2.740
# Final error: 1003.986

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %%
from random import seed
from random import randrange
from csv import reader
from math import sqrt
from sklearn import preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prettytable import PrettyTable
from sklearn.linear_model import SGDRegressor
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
import pandas as pd                                   # For Data Loading, Cleaning, Analysis and Manipulation.
import numpy as np                                    # For Mathematical Calculations and Equation Solving.

from sklearn import datasets                          # For loading the Boston DataSet.
from sklearn import preprocessing                     # For Feature Scaling.
from sklearn import model_selection                   # For train_test_split().
from sklearn.linear_model import LinearRegression     # For sklearn's LinearRegression.

# For Data Visualization :
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ch = datasets.fetch_california_housing()          # Loading the Boston DataSet.
X = ch.data                          # X/ INPUTS/ Predictor Variables/ Independent Variables.
Y = ch.target                        # Y/ OUTPUT/ Target Variable/ Dependent Variable.

# Performing the train_test_split :
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = pd.DataFrame(data = X_train, columns=ch.feature_names)
X_train['Price'] = list(Y_train)
X_test = pd.DataFrame(data = X_test, columns=ch.feature_names)
X_test['Price'] = list(Y_test)

# %%
X_train.head(7)
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  1.808122 -0.764262  0.998207   0.084854    0.436631  0.006579  1.324919
# 1  1.097891 -0.843631  0.440005   0.014431   -0.768275 -0.118332 -1.252070
# 2 -0.349490 -0.764262 -0.088795   0.245869   -0.971859 -0.011368 -0.442961
# 3  1.645924 -1.240475  0.393134  -0.194249   -1.141367 -0.027177 -0.990162
# 4 -0.717009 -0.605525 -0.395943  -0.119839    0.269744 -0.102345  1.399750
# 5  1.353249 -0.367419  0.103097  -0.299036   -0.526245  0.000412 -0.742285
# 6  0.073503 -0.208681  0.136813  -0.090322    0.727591  0.143371 -0.718900
#
#    Longitude    Price
# 0  -1.552206  3.81300
# 1   1.159540  3.29300
# 2   0.646103  1.85400
# 3   1.189449  5.00001
# 4  -0.919133  0.97500
# 5   0.735829  2.72600
# 6   0.970116  1.32000

# %%
def stocashtic_gradient_descent_regressor(X, y, learning_rate=0.2, n_epochs=1000, k=40):
    w = np.random.randn(1,8)
    b = np.random.randn(1,1)
    epoch=1
    while epoch <= n_epochs:
        temp = X.sample(k)
        X_tr = temp.iloc[:,0:8].values
        y_tr = temp.iloc[:,-1].values
        Lw = w
        Lb = b
        loss = 0
        y_pred = []
        sq_loss = []
        for i in range(k):
            Lw = (-2/k * X_tr[i]) * (y_tr[i] - np.dot(X_tr[i],w.T) - b)
            Lb = (-2/k) * (y_tr[i] - np.dot(X_tr[i],w.T) - b)

            w = w - learning_rate * Lw
            b = b - learning_rate * Lb

            y_predicted = np.dot(X_tr[i],w.T)
            y_pred.append(y_predicted)

        loss = mean_squared_error(y_pred, y_tr)
        print("Epoch: %d, Loss: %.3f" %(epoch, loss))
        epoch+=1
        learning_rate = learning_rate/1.02
    return w,b

# %%
def predict(x,w,b):
    y_pred=[]
    for i in range(len(x)):
        temp_ = x
        X_test = temp_.iloc[:,0:8].values
        y = np.asscalar(np.dot(w,X_test[i])+b)
        y_pred.append(y)
    return np.array(y_pred)
w,b = stocashtic_gradient_descent_regressor(X_train,Y_train)
y_pred_customsgd = predict(X_test,w,b)
# Out:
# Epoch: 1, Loss: 8.435
# Epoch: 2, Loss: 4.250
# Epoch: 3, Loss: 6.046
# Epoch: 4, Loss: 4.418
# Epoch: 5, Loss: 4.329
# Epoch: 6, Loss: 112.723
# Epoch: 7, Loss: 8.851
# Epoch: 8, Loss: 6.306
# Epoch: 9, Loss: 6.042
# Epoch: 10, Loss: 8.186
# Epoch: 11, Loss: 5.161
# Epoch: 12, Loss: 6.502
# Epoch: 13, Loss: 4.667
# Epoch: 14, Loss: 5.439
# Epoch: 15, Loss: 5.447
# Epoch: 16, Loss: 5.583
# Epoch: 17, Loss: 5.807
# Epoch: 18, Loss: 5.309
# Epoch: 19, Loss: 4.203
# Epoch: 20, Loss: 5.329
# Epoch: 21, Loss: 5.443
# Epoch: 22, Loss: 5.685
# Epoch: 23, Loss: 4.040
# Epoch: 24, Loss: 6.249
# Epoch: 25, Loss: 4.937
# Epoch: 26, Loss: 5.081
# Epoch: 27, Loss: 5.112
# Epoch: 28, Loss: 5.082
# Epoch: 29, Loss: 4.406
# Epoch: 30, Loss: 5.416
# Epoch: 31, Loss: 4.937
# Epoch: 32, Loss: 4.359
# Epoch: 33, Loss: 4.559
# Epoch: 34, Loss: 5.629
# Epoch: 35, Loss: 4.623
# Epoch: 36, Loss: 5.169
# Epoch: 37, Loss: 5.585
# Epoch: 38, Loss: 4.351
# Epoch: 39, Loss: 4.015
# Epoch: 40, Loss: 4.343
# Epoch: 41, Loss: 4.196
# Epoch: 42, Loss: 5.838
# Epoch: 43, Loss: 5.543
# Epoch: 44, Loss: 4.902
# Epoch: 45, Loss: 4.640
# Epoch: 46, Loss: 4.744
# Epoch: 47, Loss: 5.576
# Epoch: 48, Loss: 5.191
# Epoch: 49, Loss: 5.544
# Epoch: 50, Loss: 5.223
# Epoch: 51, Loss: 4.963
# Epoch: 52, Loss: 5.386
# Epoch: 53, Loss: 4.165
# Epoch: 54, Loss: 6.389
# Epoch: 55, Loss: 5.750
# Epoch: 56, Loss: 4.988
# Epoch: 57, Loss: 3.929
# Epoch: 58, Loss: 4.004
# Epoch: 59, Loss: 4.422
# Epoch: 60, Loss: 4.389
# Epoch: 61, Loss: 4.229
# Epoch: 62, Loss: 6.153
# Epoch: 63, Loss: 6.537
# Epoch: 64, Loss: 4.895
# Epoch: 65, Loss: 4.567
# Epoch: 66, Loss: 5.304
# Epoch: 67, Loss: 5.009
# Epoch: 68, Loss: 4.109
# Epoch: 69, Loss: 4.965
# Epoch: 70, Loss: 5.072
# Epoch: 71, Loss: 5.011
# Epoch: 72, Loss: 5.088
# Epoch: 73, Loss: 4.452
# Epoch: 74, Loss: 4.217
# Epoch: 75, Loss: 4.911
# Epoch: 76, Loss: 5.245
# Epoch: 77, Loss: 4.532
# Epoch: 78, Loss: 5.531
# Epoch: 79, Loss: 4.570
# Epoch: 80, Loss: 4.800
# Epoch: 81, Loss: 4.829
# Epoch: 82, Loss: 5.106
# Epoch: 83, Loss: 5.129
# Epoch: 84, Loss: 4.638
# Epoch: 85, Loss: 4.376
# Epoch: 86, Loss: 4.865
# Epoch: 87, Loss: 4.873
# Epoch: 88, Loss: 5.109
# Epoch: 89, Loss: 4.747
# Epoch: 90, Loss: 4.941
# Epoch: 91, Loss: 4.502
# Epoch: 92, Loss: 5.535
# Epoch: 93, Loss: 4.441
# Epoch: 94, Loss: 3.586
# Epoch: 95, Loss: 4.329
# Epoch: 96, Loss: 4.221
# Epoch: 97, Loss: 3.742
# Epoch: 98, Loss: 4.327
# Epoch: 99, Loss: 3.831
# Epoch: 100, Loss: 4.006
# Epoch: 101, Loss: 5.102
# Epoch: 102, Loss: 3.447
# Epoch: 103, Loss: 4.950
# Epoch: 104, Loss: 4.569
# Epoch: 105, Loss: 5.499
# Epoch: 106, Loss: 4.926
# Epoch: 107, Loss: 4.273
# Epoch: 108, Loss: 5.211
# Epoch: 109, Loss: 3.871
# Epoch: 110, Loss: 4.684
# Epoch: 111, Loss: 5.345
# Epoch: 112, Loss: 4.797
# Epoch: 113, Loss: 4.041
# Epoch: 114, Loss: 5.484
# Epoch: 115, Loss: 5.125
# Epoch: 116, Loss: 4.546
# Epoch: 117, Loss: 4.435
# Epoch: 118, Loss: 4.713
# Epoch: 119, Loss: 5.164
# Epoch: 120, Loss: 5.240
# Epoch: 121, Loss: 4.541
# Epoch: 122, Loss: 4.296
# Epoch: 123, Loss: 6.475
# Epoch: 124, Loss: 5.774
# Epoch: 125, Loss: 4.251
# Epoch: 126, Loss: 3.877
# Epoch: 127, Loss: 4.456
# Epoch: 128, Loss: 5.052
# Epoch: 129, Loss: 4.283
# Epoch: 130, Loss: 5.095
# Epoch: 131, Loss: 4.594
# Epoch: 132, Loss: 4.737
# Epoch: 133, Loss: 4.737
# Epoch: 134, Loss: 5.106
# Epoch: 135, Loss: 4.244
# Epoch: 136, Loss: 5.075
# Epoch: 137, Loss: 5.295
# Epoch: 138, Loss: 4.534
# Epoch: 139, Loss: 6.860
# Epoch: 140, Loss: 6.041
# Epoch: 141, Loss: 4.034
# Epoch: 142, Loss: 5.228
# Epoch: 143, Loss: 5.422
# Epoch: 144, Loss: 4.440
# Epoch: 145, Loss: 3.893
# Epoch: 146, Loss: 4.061
# Epoch: 147, Loss: 5.374
# Epoch: 148, Loss: 4.128
# Epoch: 149, Loss: 5.040
# Epoch: 150, Loss: 3.963
# Epoch: 151, Loss: 5.072
# Epoch: 152, Loss: 5.416
# Epoch: 153, Loss: 4.383
# Epoch: 154, Loss: 4.874
# Epoch: 155, Loss: 5.778
# Epoch: 156, Loss: 4.189
# Epoch: 157, Loss: 4.536
# Epoch: 158, Loss: 4.559
# Epoch: 159, Loss: 5.540
# Epoch: 160, Loss: 4.246
# Epoch: 161, Loss: 4.299
# Epoch: 162, Loss: 5.258
# Epoch: 163, Loss: 4.865
# Epoch: 164, Loss: 3.980
# Epoch: 165, Loss: 4.494
# Epoch: 166, Loss: 4.109
# Epoch: 167, Loss: 4.534
# Epoch: 168, Loss: 4.683
# Epoch: 169, Loss: 3.932
# Epoch: 170, Loss: 4.580
# Epoch: 171, Loss: 4.958
# Epoch: 172, Loss: 5.892
# Epoch: 173, Loss: 4.418
# Epoch: 174, Loss: 4.776
# Epoch: 175, Loss: 4.897
# Epoch: 176, Loss: 3.669
# Epoch: 177, Loss: 5.244
# Epoch: 178, Loss: 5.388
# Epoch: 179, Loss: 5.402
# Epoch: 180, Loss: 4.834
# Epoch: 181, Loss: 33.746
# Epoch: 182, Loss: 4.539
# Epoch: 183, Loss: 4.711
# Epoch: 184, Loss: 5.728
# Epoch: 185, Loss: 4.466
# Epoch: 186, Loss: 4.877
# Epoch: 187, Loss: 4.214
# Epoch: 188, Loss: 4.625
# Epoch: 189, Loss: 5.396
# Epoch: 190, Loss: 4.830
# Epoch: 191, Loss: 4.267
# Epoch: 192, Loss: 4.152
# Epoch: 193, Loss: 4.356
# Epoch: 194, Loss: 4.217
# Epoch: 195, Loss: 5.289
# Epoch: 196, Loss: 5.250
# Epoch: 197, Loss: 5.731
# Epoch: 198, Loss: 4.650
# Epoch: 199, Loss: 5.127
# Epoch: 200, Loss: 5.170
# Epoch: 201, Loss: 5.140
# Epoch: 202, Loss: 4.460
# Epoch: 203, Loss: 3.639
# Epoch: 204, Loss: 4.875
# Epoch: 205, Loss: 3.713
# Epoch: 206, Loss: 4.962
# Epoch: 207, Loss: 5.356
# Epoch: 208, Loss: 6.445
# Epoch: 209, Loss: 5.706
# Epoch: 210, Loss: 4.175
# Epoch: 211, Loss: 4.777
# Epoch: 212, Loss: 3.794
# Epoch: 213, Loss: 5.458
# Epoch: 214, Loss: 4.459
# Epoch: 215, Loss: 3.977
# Epoch: 216, Loss: 4.096
# Epoch: 217, Loss: 5.147
# Epoch: 218, Loss: 5.156
# Epoch: 219, Loss: 4.792
# Epoch: 220, Loss: 5.127
# Epoch: 221, Loss: 4.132
# Epoch: 222, Loss: 5.057
# Epoch: 223, Loss: 4.933
# Epoch: 224, Loss: 4.525
# Epoch: 225, Loss: 5.566
# Epoch: 226, Loss: 4.558
# Epoch: 227, Loss: 6.562
# Epoch: 228, Loss: 4.145
# Epoch: 229, Loss: 5.013
# Epoch: 230, Loss: 5.336
# Epoch: 231, Loss: 4.763
# Epoch: 232, Loss: 4.616
# Epoch: 233, Loss: 5.264
# Epoch: 234, Loss: 4.072
# Epoch: 235, Loss: 5.179
# Epoch: 236, Loss: 5.315
# Epoch: 237, Loss: 4.895
# Epoch: 238, Loss: 3.910
# Epoch: 239, Loss: 5.150
# Epoch: 240, Loss: 5.857
# Epoch: 241, Loss: 4.411
# Epoch: 242, Loss: 3.992
# Epoch: 243, Loss: 5.418
# Epoch: 244, Loss: 4.862
# Epoch: 245, Loss: 3.939
# Epoch: 246, Loss: 5.040
# Epoch: 247, Loss: 5.045
# Epoch: 248, Loss: 4.348
# Epoch: 249, Loss: 4.135
# Epoch: 250, Loss: 4.517
# Epoch: 251, Loss: 4.756
# Epoch: 252, Loss: 5.999
# Epoch: 253, Loss: 5.575
# Epoch: 254, Loss: 5.409
# Epoch: 255, Loss: 4.262
# Epoch: 256, Loss: 4.611
# Epoch: 257, Loss: 6.262
# Epoch: 258, Loss: 4.292
# Epoch: 259, Loss: 4.878
# Epoch: 260, Loss: 4.816
# Epoch: 261, Loss: 5.603
# Epoch: 262, Loss: 5.089
# Epoch: 263, Loss: 5.076
# Epoch: 264, Loss: 4.497
# Epoch: 265, Loss: 3.713
# Epoch: 266, Loss: 4.667
# Epoch: 267, Loss: 5.830
# Epoch: 268, Loss: 4.008
# Epoch: 269, Loss: 5.186
# Epoch: 270, Loss: 4.933
# Epoch: 271, Loss: 5.941
# Epoch: 272, Loss: 4.235
# Epoch: 273, Loss: 4.893
# Epoch: 274, Loss: 6.266
# Epoch: 275, Loss: 5.250
# Epoch: 276, Loss: 4.348
# Epoch: 277, Loss: 3.949
# Epoch: 278, Loss: 4.894
# Epoch: 279, Loss: 5.247
# Epoch: 280, Loss: 5.139
# Epoch: 281, Loss: 5.747
# Epoch: 282, Loss: 3.756
# Epoch: 283, Loss: 4.105
# Epoch: 284, Loss: 4.115
# Epoch: 285, Loss: 4.734
# Epoch: 286, Loss: 3.987
# Epoch: 287, Loss: 4.294
# Epoch: 288, Loss: 5.250
# Epoch: 289, Loss: 4.915
# Epoch: 290, Loss: 4.820
# Epoch: 291, Loss: 5.339
# Epoch: 292, Loss: 5.579
# Epoch: 293, Loss: 5.688
# Epoch: 294, Loss: 5.603
# Epoch: 295, Loss: 5.338
# Epoch: 296, Loss: 5.022
# Epoch: 297, Loss: 3.762
# Epoch: 298, Loss: 5.072
# Epoch: 299, Loss: 5.711
# Epoch: 300, Loss: 4.415
# Epoch: 301, Loss: 5.644
# Epoch: 302, Loss: 5.695
# Epoch: 303, Loss: 4.846
# Epoch: 304, Loss: 4.642
# Epoch: 305, Loss: 4.795
# Epoch: 306, Loss: 4.009
# Epoch: 307, Loss: 4.739
# Epoch: 308, Loss: 6.308
# Epoch: 309, Loss: 4.037
# Epoch: 310, Loss: 3.983
# Epoch: 311, Loss: 5.085
# Epoch: 312, Loss: 4.100
# Epoch: 313, Loss: 4.718
# Epoch: 314, Loss: 4.007
# Epoch: 315, Loss: 4.691
# Epoch: 316, Loss: 4.407
# Epoch: 317, Loss: 4.311
# Epoch: 318, Loss: 5.467
# Epoch: 319, Loss: 4.178
# Epoch: 320, Loss: 4.397
# Epoch: 321, Loss: 6.125
# Epoch: 322, Loss: 5.159
# Epoch: 323, Loss: 6.090
# Epoch: 324, Loss: 4.329
# Epoch: 325, Loss: 5.492
# Epoch: 326, Loss: 5.023
# Epoch: 327, Loss: 4.911
# Epoch: 328, Loss: 3.963
# Epoch: 329, Loss: 5.974
# Epoch: 330, Loss: 5.024
# Epoch: 331, Loss: 3.909
# Epoch: 332, Loss: 4.440
# Epoch: 333, Loss: 5.800
# Epoch: 334, Loss: 4.930
# Epoch: 335, Loss: 5.221
# Epoch: 336, Loss: 4.814
# Epoch: 337, Loss: 6.873
# Epoch: 338, Loss: 5.204
# Epoch: 339, Loss: 4.530
# Epoch: 340, Loss: 4.615
# Epoch: 341, Loss: 5.365
# Epoch: 342, Loss: 5.717
# Epoch: 343, Loss: 6.086
# Epoch: 344, Loss: 6.439
# Epoch: 345, Loss: 5.275
# Epoch: 346, Loss: 5.094
# Epoch: 347, Loss: 5.346
# Epoch: 348, Loss: 4.413
# Epoch: 349, Loss: 6.100
# Epoch: 350, Loss: 4.650
# Epoch: 351, Loss: 4.220
# Epoch: 352, Loss: 4.454
# Epoch: 353, Loss: 4.053
# Epoch: 354, Loss: 4.337
# Epoch: 355, Loss: 4.651
# Epoch: 356, Loss: 4.531
# Epoch: 357, Loss: 5.130
# Epoch: 358, Loss: 5.314
# Epoch: 359, Loss: 4.375
# Epoch: 360, Loss: 4.410
# Epoch: 361, Loss: 4.094
# Epoch: 362, Loss: 4.863
# Epoch: 363, Loss: 6.809
# Epoch: 364, Loss: 4.457
# Epoch: 365, Loss: 4.663
# Epoch: 366, Loss: 3.708
# Epoch: 367, Loss: 4.232
# Epoch: 368, Loss: 5.266
# Epoch: 369, Loss: 4.275
# Epoch: 370, Loss: 5.355
# Epoch: 371, Loss: 5.100
# Epoch: 372, Loss: 4.535
# Epoch: 373, Loss: 5.697
# Epoch: 374, Loss: 4.796
# Epoch: 375, Loss: 4.023
# Epoch: 376, Loss: 5.317
# Epoch: 377, Loss: 4.988
# Epoch: 378, Loss: 4.613
# Epoch: 379, Loss: 5.264
# Epoch: 380, Loss: 4.884
# Epoch: 381, Loss: 5.283
# Epoch: 382, Loss: 4.650
# Epoch: 383, Loss: 4.824
# Epoch: 384, Loss: 4.289
# Epoch: 385, Loss: 3.943
# Epoch: 386, Loss: 5.147
# Epoch: 387, Loss: 5.504
# Epoch: 388, Loss: 5.838
# Epoch: 389, Loss: 6.214
# Epoch: 390, Loss: 4.239
# Epoch: 391, Loss: 3.663
# Epoch: 392, Loss: 4.690
# Epoch: 393, Loss: 5.422
# Epoch: 394, Loss: 4.639
# Epoch: 395, Loss: 4.939
# Epoch: 396, Loss: 5.041
# Epoch: 397, Loss: 5.090
# Epoch: 398, Loss: 5.026
# Epoch: 399, Loss: 4.746
# Epoch: 400, Loss: 5.275
# Epoch: 401, Loss: 5.693
# Epoch: 402, Loss: 4.962
# Epoch: 403, Loss: 4.434
# Epoch: 404, Loss: 3.965
# Epoch: 405, Loss: 4.941
# Epoch: 406, Loss: 4.177
# Epoch: 407, Loss: 4.787
# Epoch: 408, Loss: 4.658
# Epoch: 409, Loss: 6.070
# Epoch: 410, Loss: 4.217
# Epoch: 411, Loss: 5.496
# Epoch: 412, Loss: 4.985
# Epoch: 413, Loss: 4.960
# Epoch: 414, Loss: 6.345
# Epoch: 415, Loss: 4.520
# Epoch: 416, Loss: 4.574
# Epoch: 417, Loss: 5.389
# Epoch: 418, Loss: 5.065
# Epoch: 419, Loss: 5.564
# Epoch: 420, Loss: 4.684
# Epoch: 421, Loss: 5.025
# Epoch: 422, Loss: 4.840
# Epoch: 423, Loss: 5.448
# Epoch: 424, Loss: 5.561
# Epoch: 425, Loss: 4.850
# Epoch: 426, Loss: 5.025
# Epoch: 427, Loss: 4.843
# Epoch: 428, Loss: 5.831
# Epoch: 429, Loss: 4.079
# Epoch: 430, Loss: 4.624
# Epoch: 431, Loss: 5.227
# Epoch: 432, Loss: 5.447
# Epoch: 433, Loss: 5.561
# Epoch: 434, Loss: 4.229
# Epoch: 435, Loss: 3.954
# Epoch: 436, Loss: 4.472
# Epoch: 437, Loss: 5.570
# Epoch: 438, Loss: 5.004
# Epoch: 439, Loss: 4.158
# Epoch: 440, Loss: 4.280
# Epoch: 441, Loss: 5.287
# Epoch: 442, Loss: 5.496
# Epoch: 443, Loss: 5.467
# Epoch: 444, Loss: 4.860
# Epoch: 445, Loss: 4.643
# Epoch: 446, Loss: 5.381
# Epoch: 447, Loss: 4.430
# Epoch: 448, Loss: 5.536
# Epoch: 449, Loss: 5.002
# Epoch: 450, Loss: 4.946
# Epoch: 451, Loss: 4.953
# Epoch: 452, Loss: 4.889
# Epoch: 453, Loss: 5.085
# Epoch: 454, Loss: 4.762
# Epoch: 455, Loss: 5.545
# Epoch: 456, Loss: 4.535
# Epoch: 457, Loss: 4.602
# Epoch: 458, Loss: 4.451
# Epoch: 459, Loss: 4.719
# Epoch: 460, Loss: 5.222
# Epoch: 461, Loss: 5.636
# Epoch: 462, Loss: 3.791
# Epoch: 463, Loss: 5.192
# Epoch: 464, Loss: 4.769
# Epoch: 465, Loss: 3.723
# Epoch: 466, Loss: 4.186
# Epoch: 467, Loss: 5.002
# Epoch: 468, Loss: 4.969
# Epoch: 469, Loss: 4.727
# Epoch: 470, Loss: 4.960
# Epoch: 471, Loss: 4.833
# Epoch: 472, Loss: 5.251
# Epoch: 473, Loss: 5.336
# Epoch: 474, Loss: 4.567
# Epoch: 475, Loss: 3.970
# Epoch: 476, Loss: 4.919
# Epoch: 477, Loss: 5.469
# Epoch: 478, Loss: 4.189
# Epoch: 479, Loss: 4.631
# Epoch: 480, Loss: 4.287
# Epoch: 481, Loss: 4.471
# Epoch: 482, Loss: 3.579
# Epoch: 483, Loss: 5.268
# Epoch: 484, Loss: 5.272
# Epoch: 485, Loss: 5.409
# Epoch: 486, Loss: 4.068
# Epoch: 487, Loss: 4.442
# Epoch: 488, Loss: 4.362
# Epoch: 489, Loss: 4.753
# Epoch: 490, Loss: 4.688
# Epoch: 491, Loss: 3.758
# Epoch: 492, Loss: 4.410
# Epoch: 493, Loss: 3.869
# Epoch: 494, Loss: 5.312
# Epoch: 495, Loss: 5.210
# Epoch: 496, Loss: 4.759
# Epoch: 497, Loss: 5.509
# Epoch: 498, Loss: 5.584
# Epoch: 499, Loss: 5.272
# Epoch: 500, Loss: 4.261
# Epoch: 501, Loss: 4.772
# Epoch: 502, Loss: 3.561
# Epoch: 503, Loss: 4.480
# Epoch: 504, Loss: 5.932
# Epoch: 505, Loss: 4.207
# Epoch: 506, Loss: 4.886
# Epoch: 507, Loss: 4.483
# Epoch: 508, Loss: 6.219
# Epoch: 509, Loss: 4.159
# Epoch: 510, Loss: 5.082
# Epoch: 511, Loss: 4.437
# Epoch: 512, Loss: 4.002
# Epoch: 513, Loss: 4.601
# Epoch: 514, Loss: 4.530
# Epoch: 515, Loss: 5.774
# Epoch: 516, Loss: 4.701
# Epoch: 517, Loss: 3.894
# Epoch: 518, Loss: 4.848
# Epoch: 519, Loss: 6.148
# Epoch: 520, Loss: 4.423
# Epoch: 521, Loss: 4.791
# Epoch: 522, Loss: 4.137
# Epoch: 523, Loss: 4.143
# Epoch: 524, Loss: 5.471
# Epoch: 525, Loss: 4.582
# Epoch: 526, Loss: 4.598
# Epoch: 527, Loss: 4.412
# Epoch: 528, Loss: 4.823
# Epoch: 529, Loss: 5.342
# Epoch: 530, Loss: 3.903
# Epoch: 531, Loss: 4.730
# Epoch: 532, Loss: 4.996
# Epoch: 533, Loss: 5.110
# Epoch: 534, Loss: 5.058
# Epoch: 535, Loss: 5.186
# Epoch: 536, Loss: 5.616
# Epoch: 537, Loss: 5.463
# Epoch: 538, Loss: 4.656
# Epoch: 539, Loss: 4.553
# Epoch: 540, Loss: 5.136
# Epoch: 541, Loss: 4.955
# Epoch: 542, Loss: 4.717
# Epoch: 543, Loss: 4.887
# Epoch: 544, Loss: 5.722
# Epoch: 545, Loss: 4.066
# Epoch: 546, Loss: 4.076
# Epoch: 547, Loss: 3.963
# Epoch: 548, Loss: 4.354
# Epoch: 549, Loss: 5.349
# Epoch: 550, Loss: 4.122
# Epoch: 551, Loss: 4.701
# Epoch: 552, Loss: 4.976
# Epoch: 553, Loss: 4.073
# Epoch: 554, Loss: 4.800
# Epoch: 555, Loss: 4.475
# Epoch: 556, Loss: 4.161
# Epoch: 557, Loss: 5.198
# Epoch: 558, Loss: 4.255
# Epoch: 559, Loss: 6.806
# Epoch: 560, Loss: 4.168
# Epoch: 561, Loss: 4.167
# Epoch: 562, Loss: 4.562
# Epoch: 563, Loss: 3.894
# Epoch: 564, Loss: 4.485
# Epoch: 565, Loss: 4.061
# Epoch: 566, Loss: 4.347
# Epoch: 567, Loss: 5.362
# Epoch: 568, Loss: 4.033
# Epoch: 569, Loss: 5.090
# Epoch: 570, Loss: 4.406
# Epoch: 571, Loss: 4.184
# Epoch: 572, Loss: 4.916
# Epoch: 573, Loss: 4.055
# Epoch: 574, Loss: 4.591
# Epoch: 575, Loss: 4.155
# Epoch: 576, Loss: 6.907
# Epoch: 577, Loss: 5.170
# Epoch: 578, Loss: 4.568
# Epoch: 579, Loss: 4.131
# Epoch: 580, Loss: 4.107
# Epoch: 581, Loss: 4.586
# Epoch: 582, Loss: 4.331
# Epoch: 583, Loss: 5.574
# Epoch: 584, Loss: 3.833
# Epoch: 585, Loss: 4.710
# Epoch: 586, Loss: 5.455
# Epoch: 587, Loss: 4.746
# Epoch: 588, Loss: 5.886
# Epoch: 589, Loss: 5.677
# Epoch: 590, Loss: 4.486
# Epoch: 591, Loss: 6.921
# Epoch: 592, Loss: 5.127
# Epoch: 593, Loss: 4.045
# Epoch: 594, Loss: 6.320
# Epoch: 595, Loss: 4.959
# Epoch: 596, Loss: 4.386
# Epoch: 597, Loss: 4.855
# Epoch: 598, Loss: 5.097
# Epoch: 599, Loss: 5.372
# Epoch: 600, Loss: 5.177
# Epoch: 601, Loss: 4.968
# Epoch: 602, Loss: 5.116
# Epoch: 603, Loss: 5.556
# Epoch: 604, Loss: 5.380
# Epoch: 605, Loss: 4.267
# Epoch: 606, Loss: 5.148
# Epoch: 607, Loss: 5.046
# Epoch: 608, Loss: 4.181
# Epoch: 609, Loss: 5.042
# Epoch: 610, Loss: 4.179
# Epoch: 611, Loss: 4.743
# Epoch: 612, Loss: 5.948
# Epoch: 613, Loss: 4.202
# Epoch: 614, Loss: 5.047
# Epoch: 615, Loss: 4.910
# Epoch: 616, Loss: 5.721
# Epoch: 617, Loss: 5.557
# Epoch: 618, Loss: 4.954
# Epoch: 619, Loss: 4.466
# Epoch: 620, Loss: 4.996
# Epoch: 621, Loss: 5.675
# Epoch: 622, Loss: 5.029
# Epoch: 623, Loss: 5.073
# Epoch: 624, Loss: 4.758
# Epoch: 625, Loss: 4.291
# Epoch: 626, Loss: 3.912
# Epoch: 627, Loss: 4.572
# Epoch: 628, Loss: 4.037
# Epoch: 629, Loss: 4.141
# Epoch: 630, Loss: 4.838
# Epoch: 631, Loss: 4.665
# Epoch: 632, Loss: 5.348
# Epoch: 633, Loss: 4.826
# Epoch: 634, Loss: 3.769
# Epoch: 635, Loss: 4.621
# Epoch: 636, Loss: 4.416
# Epoch: 637, Loss: 4.248
# Epoch: 638, Loss: 5.082
# Epoch: 639, Loss: 5.029
# Epoch: 640, Loss: 3.960
# Epoch: 641, Loss: 4.606
# Epoch: 642, Loss: 4.719
# Epoch: 643, Loss: 4.497
# Epoch: 644, Loss: 4.230
# Epoch: 645, Loss: 4.224
# Epoch: 646, Loss: 4.286
# Epoch: 647, Loss: 5.748
# Epoch: 648, Loss: 5.539
# Epoch: 649, Loss: 4.760
# Epoch: 650, Loss: 5.316
# Epoch: 651, Loss: 5.550
# Epoch: 652, Loss: 3.821
# Epoch: 653, Loss: 4.783
# Epoch: 654, Loss: 5.852
# Epoch: 655, Loss: 4.337
# Epoch: 656, Loss: 4.156
# Epoch: 657, Loss: 4.862
# Epoch: 658, Loss: 4.704
# Epoch: 659, Loss: 4.727
# Epoch: 660, Loss: 5.734
# Epoch: 661, Loss: 5.102
# Epoch: 662, Loss: 4.699
# Epoch: 663, Loss: 3.949
# Epoch: 664, Loss: 5.038
# Epoch: 665, Loss: 4.338
# Epoch: 666, Loss: 4.451
# Epoch: 667, Loss: 5.564
# Epoch: 668, Loss: 4.644
# Epoch: 669, Loss: 5.411
# Epoch: 670, Loss: 5.120
# Epoch: 671, Loss: 4.794
# Epoch: 672, Loss: 5.085
# Epoch: 673, Loss: 5.147
# Epoch: 674, Loss: 4.677
# Epoch: 675, Loss: 4.467
# Epoch: 676, Loss: 3.962
# Epoch: 677, Loss: 4.594
# Epoch: 678, Loss: 3.856
# Epoch: 679, Loss: 4.433
# Epoch: 680, Loss: 4.500
# Epoch: 681, Loss: 4.246
# Epoch: 682, Loss: 4.144
# Epoch: 683, Loss: 4.947
# Epoch: 684, Loss: 6.143
# Epoch: 685, Loss: 5.373
# Epoch: 686, Loss: 4.535
# Epoch: 687, Loss: 4.327
# Epoch: 688, Loss: 4.414
# Epoch: 689, Loss: 4.556
# Epoch: 690, Loss: 5.329
# Epoch: 691, Loss: 4.792
# Epoch: 692, Loss: 4.325
# Epoch: 693, Loss: 6.102
# Epoch: 694, Loss: 3.961
# Epoch: 695, Loss: 4.828
# Epoch: 696, Loss: 4.793
# Epoch: 697, Loss: 4.792
# Epoch: 698, Loss: 5.135
# Epoch: 699, Loss: 5.312
# Epoch: 700, Loss: 5.369
# Epoch: 701, Loss: 6.824
# Epoch: 702, Loss: 4.332
# Epoch: 703, Loss: 5.368
# Epoch: 704, Loss: 5.135
# Epoch: 705, Loss: 3.809
# Epoch: 706, Loss: 4.514
# Epoch: 707, Loss: 4.776
# Epoch: 708, Loss: 4.271
# Epoch: 709, Loss: 3.971
# Epoch: 710, Loss: 4.646
# Epoch: 711, Loss: 3.997
# Epoch: 712, Loss: 4.291
# Epoch: 713, Loss: 5.014
# Epoch: 714, Loss: 6.336
# Epoch: 715, Loss: 4.781
# Epoch: 716, Loss: 3.855
# Epoch: 717, Loss: 4.473
# Epoch: 718, Loss: 5.632
# Epoch: 719, Loss: 4.141
# Epoch: 720, Loss: 5.249
# Epoch: 721, Loss: 6.223
# Epoch: 722, Loss: 5.326
# Epoch: 723, Loss: 4.299
# Epoch: 724, Loss: 4.835
# Epoch: 725, Loss: 3.718
# Epoch: 726, Loss: 4.655
# Epoch: 727, Loss: 4.339
# Epoch: 728, Loss: 4.358
# Epoch: 729, Loss: 5.167
# Epoch: 730, Loss: 4.826
# Epoch: 731, Loss: 4.762
# Epoch: 732, Loss: 4.321
# Epoch: 733, Loss: 4.862
# Epoch: 734, Loss: 4.616
# Epoch: 735, Loss: 4.614
# Epoch: 736, Loss: 5.111
# Epoch: 737, Loss: 4.562
# Epoch: 738, Loss: 5.250
# Epoch: 739, Loss: 4.764
# Epoch: 740, Loss: 5.388
# Epoch: 741, Loss: 5.683
# Epoch: 742, Loss: 4.602
# Epoch: 743, Loss: 5.909
# Epoch: 744, Loss: 3.789
# Epoch: 745, Loss: 5.412
# Epoch: 746, Loss: 4.165
# Epoch: 747, Loss: 5.721
# Epoch: 748, Loss: 4.141
# Epoch: 749, Loss: 5.042
# Epoch: 750, Loss: 5.399
# Epoch: 751, Loss: 4.594
# Epoch: 752, Loss: 4.504
# Epoch: 753, Loss: 4.693
# Epoch: 754, Loss: 3.972
# Epoch: 755, Loss: 4.626
# Epoch: 756, Loss: 4.890
# Epoch: 757, Loss: 4.381
# Epoch: 758, Loss: 4.942
# Epoch: 759, Loss: 4.332
# Epoch: 760, Loss: 5.778
# Epoch: 761, Loss: 4.727
# Epoch: 762, Loss: 3.890
# Epoch: 763, Loss: 5.125
# Epoch: 764, Loss: 4.249
# Epoch: 765, Loss: 4.850
# Epoch: 766, Loss: 5.088
# Epoch: 767, Loss: 5.017
# Epoch: 768, Loss: 3.830
# Epoch: 769, Loss: 5.764
# Epoch: 770, Loss: 4.711
# Epoch: 771, Loss: 4.667
# Epoch: 772, Loss: 4.779
# Epoch: 773, Loss: 5.406
# Epoch: 774, Loss: 5.187
# Epoch: 775, Loss: 4.832
# Epoch: 776, Loss: 4.735
# Epoch: 777, Loss: 4.011
# Epoch: 778, Loss: 5.052
# Epoch: 779, Loss: 4.431
# Epoch: 780, Loss: 5.976
# Epoch: 781, Loss: 5.439
# Epoch: 782, Loss: 4.939
# Epoch: 783, Loss: 5.366
# Epoch: 784, Loss: 4.543
# Epoch: 785, Loss: 4.980
# Epoch: 786, Loss: 5.393
# Epoch: 787, Loss: 5.300
# Epoch: 788, Loss: 4.630
# Epoch: 789, Loss: 5.221
# Epoch: 790, Loss: 5.028
# Epoch: 791, Loss: 4.735
# Epoch: 792, Loss: 4.008
# Epoch: 793, Loss: 4.535
# Epoch: 794, Loss: 4.868
# Epoch: 795, Loss: 4.085
# Epoch: 796, Loss: 4.901
# Epoch: 797, Loss: 5.210
# Epoch: 798, Loss: 4.642
# Epoch: 799, Loss: 4.976
# Epoch: 800, Loss: 6.412
# Epoch: 801, Loss: 5.521
# Epoch: 802, Loss: 5.138
# Epoch: 803, Loss: 4.457
# Epoch: 804, Loss: 5.148
# Epoch: 805, Loss: 4.315
# Epoch: 806, Loss: 4.395
# Epoch: 807, Loss: 4.918
# Epoch: 808, Loss: 5.731
# Epoch: 809, Loss: 4.510
# Epoch: 810, Loss: 4.611
# Epoch: 811, Loss: 4.331
# Epoch: 812, Loss: 5.738
# Epoch: 813, Loss: 5.135
# Epoch: 814, Loss: 4.401
# Epoch: 815, Loss: 4.132
# Epoch: 816, Loss: 5.589
# Epoch: 817, Loss: 4.071
# Epoch: 818, Loss: 5.323
# Epoch: 819, Loss: 3.857
# Epoch: 820, Loss: 4.577
# Epoch: 821, Loss: 4.315
# Epoch: 822, Loss: 3.342
# Epoch: 823, Loss: 4.592
# Epoch: 824, Loss: 4.434
# Epoch: 825, Loss: 4.556
# Epoch: 826, Loss: 5.407
# Epoch: 827, Loss: 6.193
# Epoch: 828, Loss: 4.676
# Epoch: 829, Loss: 4.062
# Epoch: 830, Loss: 4.975
# Epoch: 831, Loss: 4.599
# Epoch: 832, Loss: 4.077
# Epoch: 833, Loss: 4.499
# Epoch: 834, Loss: 4.974
# Epoch: 835, Loss: 5.205
# Epoch: 836, Loss: 5.122
# Epoch: 837, Loss: 5.764
# Epoch: 838, Loss: 5.215
# Epoch: 839, Loss: 5.759
# Epoch: 840, Loss: 6.092
# Epoch: 841, Loss: 5.960
# Epoch: 842, Loss: 4.126
# Epoch: 843, Loss: 4.247
# Epoch: 844, Loss: 3.909
# Epoch: 845, Loss: 5.066
# Epoch: 846, Loss: 4.619
# Epoch: 847, Loss: 4.375
# Epoch: 848, Loss: 5.996
# Epoch: 849, Loss: 5.040
# Epoch: 850, Loss: 4.108
# Epoch: 851, Loss: 4.365
# Epoch: 852, Loss: 5.905
# Epoch: 853, Loss: 3.998
# Epoch: 854, Loss: 3.784
# Epoch: 855, Loss: 4.270
# Epoch: 856, Loss: 5.219
# Epoch: 857, Loss: 4.097
# Epoch: 858, Loss: 4.173
# Epoch: 859, Loss: 4.876
# Epoch: 860, Loss: 4.868
# Epoch: 861, Loss: 5.148
# Epoch: 862, Loss: 4.888
# Epoch: 863, Loss: 4.803
# Epoch: 864, Loss: 4.399
# Epoch: 865, Loss: 5.051
# Epoch: 866, Loss: 3.438
# Epoch: 867, Loss: 3.988
# Epoch: 868, Loss: 4.324
# Epoch: 869, Loss: 4.073
# Epoch: 870, Loss: 5.094
# Epoch: 871, Loss: 5.166
# Epoch: 872, Loss: 4.412
# Epoch: 873, Loss: 5.135
# Epoch: 874, Loss: 4.212
# Epoch: 875, Loss: 5.859
# Epoch: 876, Loss: 5.202
# Epoch: 877, Loss: 4.649
# Epoch: 878, Loss: 3.778
# Epoch: 879, Loss: 4.239
# Epoch: 880, Loss: 4.773
# Epoch: 881, Loss: 5.739
# Epoch: 882, Loss: 4.739
# Epoch: 883, Loss: 5.854
# Epoch: 884, Loss: 3.672
# Epoch: 885, Loss: 5.177
# Epoch: 886, Loss: 4.652
# Epoch: 887, Loss: 4.779
# Epoch: 888, Loss: 4.251
# Epoch: 889, Loss: 4.601
# Epoch: 890, Loss: 4.649
# Epoch: 891, Loss: 3.727
# Epoch: 892, Loss: 4.246
# Epoch: 893, Loss: 4.768
# Epoch: 894, Loss: 5.444
# Epoch: 895, Loss: 6.375
# Epoch: 896, Loss: 4.303
# Epoch: 897, Loss: 5.707
# Epoch: 898, Loss: 4.169
# Epoch: 899, Loss: 4.972
# Epoch: 900, Loss: 5.302
# Epoch: 901, Loss: 5.580
# Epoch: 902, Loss: 6.372
# Epoch: 903, Loss: 5.357
# Epoch: 904, Loss: 4.607
# Epoch: 905, Loss: 4.666
# Epoch: 906, Loss: 5.133
# Epoch: 907, Loss: 4.795
# Epoch: 908, Loss: 4.512
# Epoch: 909, Loss: 4.730
# Epoch: 910, Loss: 4.670
# Epoch: 911, Loss: 5.142
# Epoch: 912, Loss: 3.752
# Epoch: 913, Loss: 4.866
# Epoch: 914, Loss: 4.716
# Epoch: 915, Loss: 4.507
# Epoch: 916, Loss: 4.592
# Epoch: 917, Loss: 5.856
# Epoch: 918, Loss: 4.706
# Epoch: 919, Loss: 5.727
# Epoch: 920, Loss: 6.698
# Epoch: 921, Loss: 5.566
# Epoch: 922, Loss: 4.841
# Epoch: 923, Loss: 5.689
# Epoch: 924, Loss: 3.875
# Epoch: 925, Loss: 4.054
# Epoch: 926, Loss: 4.900
# Epoch: 927, Loss: 5.194
# Epoch: 928, Loss: 4.975
# Epoch: 929, Loss: 4.901
# Epoch: 930, Loss: 4.994
# Epoch: 931, Loss: 5.253
# Epoch: 932, Loss: 3.858
# Epoch: 933, Loss: 4.240
# Epoch: 934, Loss: 4.047
# Epoch: 935, Loss: 6.691
# Epoch: 936, Loss: 4.496
# Epoch: 937, Loss: 5.617
# Epoch: 938, Loss: 4.974
# Epoch: 939, Loss: 3.963
# Epoch: 940, Loss: 4.371
# Epoch: 941, Loss: 4.562
# Epoch: 942, Loss: 4.809
# Epoch: 943, Loss: 5.223
# Epoch: 944, Loss: 5.426
# Epoch: 945, Loss: 4.103
# Epoch: 946, Loss: 5.337
# Epoch: 947, Loss: 4.802
# Epoch: 948, Loss: 3.778
# Epoch: 949, Loss: 4.509
# Epoch: 950, Loss: 4.604
# Epoch: 951, Loss: 3.753
# Epoch: 952, Loss: 3.921
# Epoch: 953, Loss: 4.248
# Epoch: 954, Loss: 4.625
# Epoch: 955, Loss: 4.280
# Epoch: 956, Loss: 4.031
# Epoch: 957, Loss: 4.720
# Epoch: 958, Loss: 4.127
# Epoch: 959, Loss: 5.036
# Epoch: 960, Loss: 5.358
# Epoch: 961, Loss: 5.185
# Epoch: 962, Loss: 4.431
# Epoch: 963, Loss: 4.402
# Epoch: 964, Loss: 5.318
# Epoch: 965, Loss: 4.962
# Epoch: 966, Loss: 4.222
# Epoch: 967, Loss: 4.496
# Epoch: 968, Loss: 6.171
# Epoch: 969, Loss: 3.974
# Epoch: 970, Loss: 4.808
# Epoch: 971, Loss: 4.821
# Epoch: 972, Loss: 5.600
# Epoch: 973, Loss: 5.861
# Epoch: 974, Loss: 4.530
# Epoch: 975, Loss: 3.814
# Epoch: 976, Loss: 4.239
# Epoch: 977, Loss: 4.167
# Epoch: 978, Loss: 5.106
# Epoch: 979, Loss: 4.297
# Epoch: 980, Loss: 3.998
# Epoch: 981, Loss: 5.020
# Epoch: 982, Loss: 4.329
# Epoch: 983, Loss: 4.223
# Epoch: 984, Loss: 5.536
# Epoch: 985, Loss: 4.728
# Epoch: 986, Loss: 5.089
# Epoch: 987, Loss: 5.381
# Epoch: 988, Loss: 4.234
# Epoch: 989, Loss: 3.805
# Epoch: 990, Loss: 5.860
# Epoch: 991, Loss: 5.831
# Epoch: 992, Loss: 5.739
# Epoch: 993, Loss: 5.723
# Epoch: 994, Loss: 4.300
# Epoch: 995, Loss: 5.119
# Epoch: 996, Loss: 5.118
# Epoch: 997, Loss: 4.298
# Epoch: 998, Loss: 5.166
# Epoch: 999, Loss: 5.235
# Epoch: 1000, Loss: 4.333
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-9a75012aafc8> in <cell line: 10>()
#       8     return np.array(y_pred)
#       9 w,b = stocashtic_gradient_descent_regressor(X_train,Y_train)
# ---> 10 y_pred_customsgd = predict(X_test,w,b)
#
# <ipython-input-35-9a75012aafc8> in predict(x, w, b)
#       4         temp_ = x
#       5         X_test = temp_.iloc[:,0:8].values
# ----> 6         y = np.asscalar(np.dot(w,X_test[i])+b)
#       7         y_pred.append(y)
#       8     return np.array(y_pred)
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     309             return Tester
#     310
# --> 311         raise AttributeError("module {!r} has no attribute "
#     312                              "{!r}".format(__name__, attr))
#     313
#
# AttributeError: module 'numpy' has no attribute 'asscalar'
